# %% [markdown]
# <a href="https://colab.research.google.com/github/jabc2139-pixel/Internship-Unified-mentor/blob/main/DAY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DAY1

# %% [markdown]
# **PYTHON data types, type casting and variables**
#
# *   text type : str
# *   numeric type : int , float
# *   sequence type : list, tuple, range
# *   set type =     set
# *   boolean type : bool

# %%
name = "karishma"
age = 22
percent = 88.63
type(percent)
# Out:
# float

# %%
student1 = ['karishma',22,88.63]      #list        --> Can modify
student2 = ('karishma',22,88.63)      # tuple     --> Cannot modify
student3 = {'karishma',22,88.63}      # set       --> Random output
type(student3)
# Out:
# {88.63, 'karishma', 22}

# %%
student3                               # run student1, student2, student3 see the output diff
# Out:
# {88.63, 'karishma', 22}

# %%
student = {'Name': 'karishma','Age': 22, 'Percent': 88.63}
student.keys()
# Out:
# dict_keys(['Name', 'Age', 'Percent'])

# %%
print(student.values())
# Out:
# dict_values(['karishma', 22, 88.63])

# %%
bool(0)
# Out:
# False

# %%
bool(-1)
# Out:
# True

# %%
bool(1)
# Out:
# True
